# %% [markdown]
# module2

# %%
def myfun(*args):
    for arg in args:
        print(arg)

myfun("hello","to","world","python",23,45 )
# Out:
# hello
# to
# world
# python
# 23
# 45

# %%
def myfun(**args):
    for key ,value in args.items():
        print("%s==%s" %(key,value))

myfun(first="hello",mid="to",last="world" )
# Out:
# first==hello
# mid==to
# last==world

# %%
out=" \n python"

def f1():
    s='hello'
    c='\t python'
    b=s+c
    def f2():
        print(b,out)

    f2()
f1()
# Out:
# hello	 python
#  python

# %%
def f():
    print(s)
f()
s="hello"
# Out:
# hello
